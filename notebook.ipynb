# %%
import pandas as pd

# %%
######## key steps 
          1.identify the important columns Game Analytics Agent
                appid
                required_age  
                controller_support
                pc_requirements  
                about_the_game
                developers 
                publishers
                price_overview
                reviews
                release_date
                name
                is_free
                price
                positive
                negative
                genres
                supported_languages
                release_date
                categories
                tags
                content_descriptors 
         2. remove duplicate values and drop null values 
         3.re

# %%
df  =  pd.read_csv("C://Users//Deepak//Desktop//Agentic Ai Training Code//Data//game_data.csv")

# %%
df.shape
# Out:
# (29235, 34)

# %%
## here 1 tast preprocessing.....................

# %%
df1 =  pd.read_csv("C://Users//Deepak//Desktop//Agentic Ai Training Code//Data//game_data.csv")
df.head()
df1.shape
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 df1 =  pd.read_csv("C://Users//Deepak//Desktop//Agentic Ai Training Code//Data//game_data.csv")
#       2 df.head()
#       3 df1.shape
#
# ...

# %%
df2  =  pd.read_csv("C://Users//Deepak//Desktop//Agentic Ai Training Code//Data//game_ids.csv")
df2.head()
df2.shape
# Out:
# (29235, 2)

# %%
df3  = pd.read_csv("C://Users//Deepak//Desktop//Agentic Ai Training Code//Data//additional_data.csv")
df.head()
df3.shape
# Out:
# (29235, 20)

# %%
##

df1.drop_duplicates(inplace=True)
df1.shape
# Out:
# (29228, 34)

# %%
df2.drop_duplicates(inplace=True)
df2.shape
# Out:
# (29235, 2)

# %%
df3.drop_duplicates(inplace=True)
df3.shape
# Out:
# (29235, 20)

# %%
#### 
print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['type', 'name', 'steam_appid', 'required_age', 'is_free',
#        'controller_support', 'detailed_description', 'about_the_game',
#        'short_description', 'fullgame', 'supported_languages', 'header_image',
#        'website', 'pc_requirements', 'mac_requirements', 'linux_requirements',
#        'developers', 'publishers', 'price_overview', 'packages',
#        'package_groups', 'platforms', 'metacritic', 'reviews', 'categories',
#        'genres', 'screenshots', 'movies', 'recommendations', 'achievements',
#        'release_date', 'support_info', 'background', 'content_descriptors'],
#       dtype='object')
# Index(['appid', 'name'], dtype='object')
# Index(['appid', 'name', 'developer', 'publisher', 'score_rank', 'positive',
#        'negative', 'userscore', 'owners', 'average_forever', 'average_2weeks',
#        'median_forever', 'median_2weeks', 'price', 'initialprice', 'discount',
#        'languages', 'genre', 'ccu', 'tags'],
#       dtype='object')

# %%
####

df3.isnull().sum()
# Out:
# appid                  0
# name                   5
# developer            198
# publisher            296
# score_rank         29177
# positive               0
# negative               0
# userscore              0
# owners                 0
# average_forever        0
# average_2weeks         0
# median_forever         0
# median_2weeks          0
# price                 29
# initialprice          22
# discount              22
# languages             94
# genre                152
# ccu                    0
# tags                   0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# appid    0
# name     5
# dtype: int64

# %%
df1.isnull().sum()
# Out:
# type                      149
# name                        1
# steam_appid                 0
# required_age              149
# is_free                   149
# controller_support      23230
# detailed_description      175
# about_the_game            175
# short_description         175
# fullgame                29228
# supported_languages       163
# header_image              149
# website                  9979
# pc_requirements           149
# mac_requirements          149
# linux_requirements        149
# developers                264
# publishers                149
# price_overview           3712
# packages                 3370
# package_groups            149
# platforms                 149
# metacritic              26253
# reviews                 23323
# categories                714
# genres                    196
# screenshots               177
# movies                   2071
# recommendations         22504
# achievements             2381
# release_date              149
# ...

# %%
df1.head()
# Out:
#    type                       name  steam_appid  required_age is_free  \
# 0  game             Counter-Strike           10           0.0   False
# 1  game      Team Fortress Classic           20           0.0   False
# 2  game              Day of Defeat           30           0.0   False
# 3  game         Deathmatch Classic           40           0.0   False
# 4  game  Half-Life: Opposing Force           50           0.0   False
#
#   controller_support                               detailed_description  \
# 0                NaN  Play the world's number 1 online action game. ...
# 1                NaN  One of the most popular online action games of...
# 2                NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3                NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4                NaN  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# ...

# %%
df1['release_date']
# Out:
# 0         {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1         {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2         {'coming_soon': False, 'date': '1 May, 2003'}
# 3         {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4         {'coming_soon': False, 'date': '1 Nov, 1999'}
#                               ...
# 29230    {'coming_soon': False, 'date': '24 Apr, 2019'}
# 29231    {'coming_soon': False, 'date': '23 Apr, 2019'}
# 29232    {'coming_soon': False, 'date': '24 Apr, 2019'}
# 29233    {'coming_soon': False, 'date': '17 Apr, 2019'}
# 29234    {'coming_soon': False, 'date': '24 Apr, 2019'}
# Name: release_date, Length: 29235, dtype: object

# %%
### columns needed is  
steam_appid / appid
required_age  
controller_support
pc_requirements  
about_the_game
developers 
publishers
price_overview
reviews
release_date
name
is_free
price
positive
negative
genres
supported_languages
release_date
categories
tags
content_descriptors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 ### columns needed is
# ----> 2 steam_appid / appid
#       3 required_age
#       4 controller_support
#
# NameError: name 'steam_appid' is not defined

# %%
df = df1.merge(df3, left_on="steam_appid", right_on="appid", how="inner")
df.head()
# Out:
#    type                     name_x  steam_appid  required_age is_free  \
# 0  game             Counter-Strike           10           0.0   False
# 1  game      Team Fortress Classic           20           0.0   False
# 2  game              Day of Defeat           30           0.0   False
# 3  game         Deathmatch Classic           40           0.0   False
# 4  game  Half-Life: Opposing Force           50           0.0   False
#
#   controller_support                               detailed_description  \
# 0                NaN  Play the world's number 1 online action game. ...
# 1                NaN  One of the most popular online action games of...
# 2                NaN  Enlist in an intense brand of Axis vs. Allied ...
# 3                NaN  Enjoy fast-paced multiplayer gaming with Death...
# 4                NaN  Return to the Black Mesa Research Facility as ...
#
#                                       about_the_game  \
# 0  Play the world's number 1 online action game. ...
# ...

# %%
required_columns = [
    "steam_appid",
    "required_age",
    "pc_requirements",
    "about_the_game",
    "developers",
    "publishers",
    "price_overview",
    "release_date",
    "name_x",      
    "is_free",
    "price",
    "positive",
    "negative",
    "genres",
    "supported_languages",
    "categories",
    "tags",
    "content_descriptors"
]

df = df[required_columns]

# %%
df.head()
# Out:
#    steam_appid  required_age  \
# 0           10           0.0
# 1           20           0.0
# 2           30           0.0
# 3           40           0.0
# 4           50           0.0
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                       about_the_game            developers  \
# 0  Play the world's number 1 online action game. ...             ['Valve']
# 1  One of the most popular online action games of...             ['Valve']
# 2  Enlist in an intense brand of Axis vs. Allied ...             ['Valve']
# 3  Enjoy fast-paced multiplayer gaming with Death...             ['Valve']
# 4  Return to the Black Mesa Research Facility as ...  ['Gearbox Software']
#
# ...

# %%
df.head()
# Out:
#    steam_appid  required_age  \
# 0           10           0.0
# 1           20           0.0
# 2           30           0.0
# 3           40           0.0
# 4           50           0.0
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                       about_the_game            developers  \
# 0  Play the world's number 1 online action game. ...             ['Valve']
# 1  One of the most popular online action games of...             ['Valve']
# 2  Enlist in an intense brand of Axis vs. Allied ...             ['Valve']
# 3  Enjoy fast-paced multiplayer gaming with Death...             ['Valve']
# 4  Return to the Black Mesa Research Facility as ...  ['Gearbox Software']
#
# ...

# %%
df.columns
# Out:
# Index(['steam_appid', 'required_age', 'pc_requirements', 'about_the_game',
#        'developers', 'publishers', 'price_overview', 'release_date', 'name_x',
#        'is_free', 'price', 'positive', 'negative', 'genres',
#        'supported_languages', 'categories', 'tags', 'content_descriptors'],
#       dtype='object')

# %%
df['name_x']
# Out:
# 0                    Counter-Strike
# 1             Team Fortress Classic
# 2                     Day of Defeat
# 3                Deathmatch Classic
# 4         Half-Life: Opposing Force
#                     ...
# 29228               Room of Pandora
# 29229                     Cyber Gun
# 29230              Super Star Blast
# 29231    New Yankee 7: Deer Hunters
# 29232                     Rune Lord
# Name: name_x, Length: 29233, dtype: object

# %%
df.isnull().sum()
# Out:
# steam_appid               0
# required_age            149
# pc_requirements         149
# about_the_game          175
# developers              264
# publishers              149
# price_overview         3712
# release_date            149
# name_x                    1
# is_free                 149
# price                    29
# positive                  0
# negative                  0
# genres                  196
# supported_languages     163
# categories              714
# tags                      0
# content_descriptors     149
# dtype: int64

# %%
df.columns
# Out:
# Index(['steam_appid', 'required_age', 'pc_requirements', 'about_the_game',
#        'developers', 'publishers', 'price_overview', 'release_date', 'name_x',
#        'is_free', 'price', 'positive', 'negative', 'genres',
#        'supported_languages', 'categories', 'tags', 'content_descriptors'],
#       dtype='object')

# %%
df['release_date']
# Out:
# 0         {'coming_soon': False, 'date': '1 Nov, 2000'}
# 1         {'coming_soon': False, 'date': '1 Apr, 1999'}
# 2         {'coming_soon': False, 'date': '1 May, 2003'}
# 3         {'coming_soon': False, 'date': '1 Jun, 2001'}
# 4         {'coming_soon': False, 'date': '1 Nov, 1999'}
#                               ...
# 29228    {'coming_soon': False, 'date': '24 Apr, 2019'}
# 29229    {'coming_soon': False, 'date': '23 Apr, 2019'}
# 29230    {'coming_soon': False, 'date': '24 Apr, 2019'}
# 29231    {'coming_soon': False, 'date': '17 Apr, 2019'}
# 29232    {'coming_soon': False, 'date': '24 Apr, 2019'}
# Name: release_date, Length: 29233, dtype: object

# %%
df.shape
# Out:
# (29233, 18)

# %%
df.dropna(subset= ['about_the_game', 'developers','publishers','price_overview','release_date','is_free','price','genres','supported_languages','categories','content_descriptors'],inplace = True)

# %%
df.shape
# Out:
# (24989, 18)

# %%
df.isnull().sum()
# Out:
# steam_appid            0
# required_age           0
# pc_requirements        0
# about_the_game         0
# developers             0
# publishers             0
# price_overview         0
# release_date           0
# name_x                 0
# is_free                0
# price                  0
# positive               0
# negative               0
# genres                 0
# supported_languages    0
# categories             0
# tags                   0
# content_descriptors    0
# dtype: int64

# %%
df.to_csv('C://Users//Deepak//Desktop//Agentic Ai Training Code//Data//game_cleaned_file.csv', index=False)

# %%
data = pd.read_csv("C://Users//Deepak//Desktop//Agentic Ai Training Code//Data//game_cleaned_file.csv")
data.head()
# Out:
#    steam_appid  required_age  \
# 0           10           0.0
# 1           20           0.0
# 2           30           0.0
# 3           40           0.0
# 4           50           0.0
#
#                                      pc_requirements  \
# 0  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 1  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 2  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 3  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
# 4  {'minimum': '\r\n\t\t\t<p><strong>Minimum:</st...
#
#                                       about_the_game            developers  \
# 0  Play the world's number 1 online action game. ...             ['Valve']
# 1  One of the most popular online action games of...             ['Valve']
# 2  Enlist in an intense brand of Axis vs. Allied ...             ['Valve']
# 3  Enjoy fast-paced multiplayer gaming with Death...             ['Valve']
# 4  Return to the Black Mesa Research Facility as ...  ['Gearbox Software']
#
# ...

# %%
data.columns
# Out:
# Index(['steam_appid', 'required_age', 'pc_requirements', 'about_the_game',
#        'developers', 'publishers', 'price_overview', 'release_date', 'name_x',
#        'is_free', 'price', 'positive', 'negative', 'genres',
#        'supported_languages', 'categories', 'tags', 'content_descriptors'],
#       dtype='object')

# %%
data['name_x'=Counter-Strike]
# Out:
#   Cell In[111], line 1
#     data['name_x'=Counter-Strike]
#          ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
// question 1
To answer your question, let's analyze the data.\n\nWe have two games: one that is free and one that is paid. The free game has a positive rating of 1753.73 and a negative rating of 392.42. The paid game has a positive rating of 780.50 and a negative rating of 165.73.\n\nTo compare the ratings, let's calculate the average rating for each game. The average rating is calculated by adding the positive and negative ratings and then dividing by 2.\n\nFor the free game, the average rating is (1753.73 + 392.42) / 2 = 1128.075.\n\nFor the paid game, the average rating is (780.50 + 165.73) / 2 = 473.115.\n\nBased on this analysis, the free game has a significantly higher average rating (1128.075) compared to the paid game (473.115). This suggests that, on average, free games tend to have higher ratings than paid games.\n\nHowever, it's essential to note that this is based on a very small dataset and might not be representative of all games. A larger dataset would provide more accurate insights. Nevertheless, this result is intriguing and could be worth exploring further.\n\nIf you'd like to analyze more data or have any follow-up questions, feel free to ask!

{"status":"Success","type":"table","generated_code":"result = df.groupby('is_free')[['positive', 'negative']].mean().reset_index()","data":[{"is_free":false,"positive":780.4995789389261,"negative":165.7314833380118},{"is_free":true,"positive":1753.7307692307693,"negative":392.4230769230769}],"llm_message":"To answer your question, let's analyze the data.\n\nWe have two games: one that is free and one that is paid. The free game has a positive rating of 1753.73 and a negative rating of 392.42. The paid game has a positive rating of 780.50 and a negative rating of 165.73.\n\nTo compare the ratings, let's calculate the average rating for each game. The average rating is calculated by adding the positive and negative ratings and then dividing by 2.\n\nFor the free game, the average rating is (1753.73 + 392.42) / 2 = 1128.075.\n\nFor the paid game, the average rating is (780.50 + 165.73) / 2 = 473.115.\n\nBased on this analysis, the free game has a significantly higher average rating (1128.075) compared to the paid game (473.115). This suggests that, on average, free games tend to have higher ratings than paid games.\n\nHowever, it's essential to note that this is based on a very small dataset and might not be representative of all games. A larger dataset would provide more accurate insights. Nevertheless, this result is intriguing and could be worth exploring further.\n\nIf you'd like to analyze more data or have any follow-up questions, feel free to ask!"}
 
 [{'is_free': False, 'positive': 780.4995789389261, 'negative': 165.7314833380118}, {'is_free': True, 'positive': 1753.7307692307693, 'negative': 392.4230769230769}]

# %%
## question 2 
950 
{"status":"Success","type":"table","generated_code":"result = df.groupby('is_free')[['positive', 'negative']].mean().reset_index()","data": 950 ,"llm_message":"950 Action games support Korean language."}
 
result = df[df['genres'].str.contains('Action') & df['supported_languages'].str.contains('Korean')].shape[0]
Generated Pandas Code:
 result = df[df['genres'].str.contains('Action') & df['supported_languages'].str.contains('Korean')].shape[0]
Data Result:
 950

# %%
## question 3 
['iRacing', 'Minimon', 'ShellShock Live', 'Musclecar Online', 'SURVIVAL', 'Break_In', 'Elite Dangerous', 'Choice Chamber', 'Once Bitten, Twice Dead!', 'WarBirds - World War II Combat Aviation', 'Spy Bugs', 'Assault Corps 2', 'The Isle', 'Demon Horde Master', 'ABD: A Beautiful Day', 'Heaven Island - VR MMO', 'Lonath Online', 'Elements: Epic Heroes', 'Drift Streets Japan']

```python
result = df[df['release_date'].str.contains('2015|2016|2017|2018|2019|2020|2021|2022|2023')]['genres'].str.split('],[').explode().str.strip('[]\'').str.split(',').apply(lambda x: x[0]).str.contains('Shooter').reset_index()
result = result[result['index'].duplicated(keep=False)].sort_values(by='index', ascending=False).head(10)
```
Generated Pandas Code:
 ```python
result = df[df['release_date'].str.contains('2015|2016|2017|2018|2019|2020|2021|2022|2023')]['genres'].str.split('],[').explode().str.strip('[]\'').str.split(',').apply(lambda x: x[0]).str.contains('Shooter').reset_index()
result = result[result['index'].duplicated(keep=False)].sort_values(by='index', ascending=False).head(10)

# %%
## question  4
999.0 


result = df.loc[df['name_x'] == 'Counter-Strike', 'price_overview'].apply(lambda x: x['final_formatted']).iloc[0]
price_overview = df.loc[df['name_x'] == 'Counter-Strike', 'price_overview'].iloc[0]
price = price_overview['final']
currency = price_overview['currency']
if currency == 'GBP':
    price_inr = price * 87.5
    price_usd = price * 1.31
else:
    price_inr = price
    price_usd = price
result = {'INR': price_inr, 'USD': price_usd}
Generated Pandas Code:
 result = df.loc[df['name_x'] == 'Counter-Strike', 'price_overview'].apply(lambda x: x['final_formatted']).iloc[0]
price_overview = df.loc[df['name_x'] == 'Counter-Strike', 'price_overview'].iloc[0]
price = price_overview['final']
currency = price_overview['currency']
if currency == 'GBP':
    price_inr = price * 87.5
    price_usd = price * 1.31
else:
    price_inr = price
    price_usd = price
result = {'INR': price_inr, 'USD': price_usd}
